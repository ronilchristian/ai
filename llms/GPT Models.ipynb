# %% [markdown]
# ### Setting up the API

# %%
import openai
import config

# %%
api_key = config.api_key

# %%
openai.api_key = api_key

# %% [markdown]
# ### Generating text

# %%
def generate_text(prompt):
    response = openai.Completion.create(
        engine = "davinci-002",
        prompt = prompt,
        max_tokens = 10,
        temperature = 0.7
    )

    return response.choices[0].text.strip()

# %%
prompt = "Once upon a time"

# %%
generated_text = generate_text(prompt)

# %%
print(prompt, generated_text)
# Out:
# Once upon a time , I read a book called “The Tao of

# %% [markdown]
# ### Cutomizing the output

# %%
def generate_text(prompt, max_tokens, temperature):
    response = openai.Completion.create(
        engine = "davinci-002",
        prompt = prompt,
        max_tokens = max_tokens,
        temperature = temperature
    )

    return response.choices[0].text.strip()

# %%
generated_text = generate_text(prompt, 50, 0)
print(prompt, generated_text)
# Out:
# Once upon a time , there was a little girl who was born with a very special gift. She could see things that others could not. She could see the future, and she could see the past. She could see the present, and she could see the future.

# %%
generated_text = generate_text(prompt, 50, 1)
print(prompt, generated_text)
# Out:
# Once upon a time Sweden went ahead to designate Bland Aldre by Argentinian composer Alberto Ginastera as “masterwork”.
#
# It's good to hear the Bamberg Symphony's finest still playing their gorgeous best.
#
# Forsyth's sharp-edged Four Days sounds
